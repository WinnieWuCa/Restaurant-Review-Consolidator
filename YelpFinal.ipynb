# %%
# Project 2 - Yelp API

# %%
# !pip install yelpapi

# %%
# Dependencies and Setup
import requests
import json
import pandas as pd

# Import API key
from api_keys import api_key

# %%
api_key='QWMy8-jFwxoKJkLNvzLl-jDymYjp-bN83izdcDMb91a3JG5h_8XRcjYNWWSXYhKjo0cPdnC_UdrnlAaap6kwUqa3Cqm2dCU202lvbXL3AkUqJ_m7PQAFKlqnvmGyXHYx'

headers = {'Authorization': 'Bearer %s' % api_key}

# %%
url='https://api.yelp.com/v3/businesses/search'

# %% [markdown]
# # New York

# %%
# Perform API Calls - test with one restaurant 
params_ld = {'term':'restaurant',
             'location':'New York', 
             'sort_by': 'rating',    
             'limit':'50'}

# %%
request=requests.get(url, params=params_ld, headers=headers)
print('The status code is {}'.format(request.status_code))
# Out:
# The status code is 200

# %%
#Convert the data into a JSON object
parsed_ld = json.loads(request.text)
newyork = parsed_ld["businesses"]

# %%
#“businesses” is a list, enclosed by a square brackets.
# extract businesses first into a Python list and then loop over the businesses in the list.
# count = 1
name = []
phone_number = []
postal_code =[]
address = []
city = []
rating = []
category = []
cost = []
review_count = []
 

for business in newyork:
    #print("Number:", count)
    #print("Name:", business["name"])
    #print("Address:", " ".join(business["location"]["display_address"]))
    #print("City:", " ".join(business["location"]["city"]))
    #print("Rating:", business["rating"])
    #print("Category:", business["categories"][0].get('alias'))
        
    #if 'price' in business:
    #    print("Cost:", business["price"])
    #
    #print("\n")
    #print("Review Count:", business["review_count"])
    
    name.append(business["name"])
    #phone_number.append(business["phone"])  
    phone_number.append(str(business["phone"])) 
    postal_code.append(business["location"]["zip_code"])
    address.append(str(business["location"]["display_address"]))
    city.append(business["location"]["city"])
    rating.append(business["rating"])
    category.append(business["categories"][0].get('alias'))
    
    
    if 'price' in business:
        cost.append(business["price"])
    else:
        cost.append("")
    review_count.append(business["review_count"])

    
    # count = count+1

# %%
df_ny = pd.DataFrame(data={"name": name, "phone_number": phone_number,"postal_code": postal_code, "address": address, "city": city, "rating":
                       rating, "category": category, "cost": cost, "review_Count": review_count})
df_ny
# Out:
#                              name  phone_number postal_code  \
# 0                            Otis  +16468860601       11206
# 1                      The Alcove  +13478134159       11104
# 2                 Taste of Heaven  +17185763146       11211
# 3                   Korai Kitchen  +12017216566       07306
# 4                Andrea Salumeria  +12016531666       07307
# 5            L'industrie Pizzeria  +17185990002       11211
# 6                  Los Tacos No.1  +12125744696       10036
# 7          Royal Grill Halal Food  +13477240504       10036
# 8                   Miscelanea NY  +12122530277       10003
# 9   Hold Fast Kitchen and Spirits  +19172616691       10036
# 10               Green Juice Cafe  +16469187730       10033
# 11                 Joey Bats Café  +12129511189       10002
# 12                     Cafe Talya  +12015355333       07002
# 13                 Los Tacos No.1  +12122560343       10011
# 14      Koroni Souvlaki and Grill  +17184898820       11102
# 15                 Non Solo Piada  +12122160616       10018
# 16    Sal, Kris, & Charlie's Deli  +17182789240       11105
# 17                    Pita Palace  +17183830550       11211
# 18                  Samurai Sushi  +12018961760       07073
# 19         Tony's Beechhurst Deli  +17187678222       11357
# 20           Frenchy's Food Truck  +16464682861       11238
# 21               Baba's Pierogies  +17182220777       11215
# 22      Sushi by Bou Times Square                     10036
# 23           Second Street Bakery  +12014201793       07302
# 24               Lella Alimentari  +17185992625       11211
# 25                    Casa d'Paco  +18623079466       07105
# 26                      Sushi Lin  +13476276027       11217
# 27                   Los Mariscos  +12129204986       10011
# 28              191 Knickerbocker  +19293053625       11237
# 29          Fiore Deli of Hoboken  +12016591655       07030
# 30                         Jajaja  +16468835453       10002
# 31                  Mughlai Grill  +12125332828       10002
# 32             Sami's Kabab House  +19178327165       11106
# 33            4 Charles Prime Rib  +12125615992       10014
# 34        Aux Merveilleux De Fred  +19174751992       10014
# 35                  Laojie Hotpot  +17184310026       11220
# 36               Tres Leches Cafe  +16465590176       10029
# 37                     Griot Cafe  +12014209444       07307
# 38                Kafe Louverture  +13473053176       11216
# 39                Mysttik Masaala  +19173063128       10022
# 40     Sorriso Italian Pork Store  +17187284392       11103
# 41               Panzerotti Bites  +17184889300       11231
# 42                   Dian Kitchen  +16465909898       10009
# 43            Three Seat Espresso  +19173882769       10009
# 44                 Loi Estiatorio  +12127130015       10019
# 45          Lillo Cucina Italiana  +13477630899       11201
# 46               Frisson Espresso  +16468503928       10036
# 47             Top Thai Greenwich  +16467264418       10012
# 48             Joe's Italian Deli  +17183677979       10458
# 49                        Ruffian                     10009
#
#                                               address             city  \
# 0            ['18 Harrison Pl', 'Brooklyn, NY 11206']         Brooklyn
# 1            ['41-11 49th St', 'Sunnyside, NY 11104']        Sunnyside
# 2            ['251 Jackson St', 'Brooklyn, NY 11211']         Brooklyn
# 3         ['576 Summit Ave', 'Jersey City, NJ 07306']      Jersey City
# 4   ['247 Central Ave', 'Apt 3', 'Jersey City, NJ ...      Jersey City
# 5              ['254 S 2nd St', 'Brooklyn, NY 11211']         Brooklyn
# 6             ['229 W 43rd St', 'New York, NY 10036']         New York
# 7       ['44th St And 6th Ave', 'New York, NY 10036']         New York
# 8               ['63 E 4th St', 'New York, NY 10003']         New York
# 9              ['364 W46th St', 'New York, NY 10036']         New York
# 10            ['4316 Broadway', 'New York, NY 10033']         New York
# 11             ['129 Allen St', 'New York, NY 10002']         New York
# 12                 ['218 Ave B', 'Bayonne, NJ 07002']          Bayonne
# 13               ['75 9th Ave', 'New York, NY 10011']         New York
# 14         ['29-37 Newtown Ave', 'Astoria, NY 11102']          Astoria
# 15            ['302 W 37th St', 'New York, NY 10018']         New York
# 16            ['33-12 23rd Ave', 'Astoria, NY 11105']          Astoria
# 17           ['413 Graham Ave', 'Brooklyn, NY 11211']         Brooklyn
# 18      ['254 Park Ave', 'East Rutherford, NJ 07073']  East Rutherford
# 19          ['1118 154th St', 'Whitestone, NY 11357']       Whitestone
# 20         ['341 Eastern Pkwy', 'Brooklyn, NY 11238']         Brooklyn
# 21              ['295 3rd Ave', 'Brooklyn, NY 11215']         Brooklyn
# 22            ['132 W 47th St', 'New York, NY 10036']         New York
# 23            ['402 2nd St', 'Jersey City, NJ 07302']      Jersey City
# 24        ['325 Manhattan Ave', 'Brooklyn, NY 11211']         Brooklyn
# 25              ['73 Warwick St', 'Newark, NJ 07105']           Newark
# 26         ['335 Flatbush Ave', 'Brooklyn, NY 11217']         Brooklyn
# 27            ['409 W 15th St', 'New York, NY 10011']         New York
# 28    ['191 Knickerbocker Ave', 'Brooklyn, NY 11237']         Brooklyn
# 29              ['414 Adams St', 'Hoboken, NJ 07030']          Hoboken
# 30           ['162 E Broadway', 'New York, NY 10002']         New York
# 31             ['6 Clinton St', 'New York, NY 10002']         New York
# 32         ['35-57 Crescent St', 'Astoria, NY 11106']          Astoria
# 33             ['4 Charles St', 'New York, NY 10014']         New York
# 34               ['37 8th Ave', 'New York, NY 10014']         New York
# 35              ['811 53rd St', 'Brooklyn, NY 11220']         Brooklyn
# 36           ['356 E 112th St', 'New York, NY 10029']         New York
# 37       ['434 Central Ave', 'Jersey City, NJ 07307']      Jersey City
# 38            ['392 Halsey St', 'Brooklyn, NY 11216']         Brooklyn
# 39  ['399 Park Ave', 'Corner of 54th street', 'New...         New York
# 40             ['4416 30th Ave', 'Astoria, NY 11103']          Astoria
# 41             ['235 Smith St', 'Brooklyn, NY 11231']         Brooklyn
# 42             ['435 E 9th St', 'New York, NY 10009']         New York
# 43             ['137 Avenue A', 'New York, NY 10009']         New York
# 44            ['132 W 58th St', 'New York, NY 10019']         New York
# 45             ['331 Henry St', 'Brooklyn, NY 11201']         Brooklyn
# 46            ['326 W 47th St', 'New York, NY 10036']         New York
# 47          ['235 Sullivan St', 'New York, NY 10012']         New York
# 48              ['685 E 187th St', 'Bronx, NY 10458']            Bronx
# 49             ['125 E 7th St', 'New York, NY 10009']         New York
#
#     rating          category cost  review_Count
# 0      5.0       newamerican   $$           172
# 1      5.0        gastropubs   $$           677
# 2      5.0          soulfood   $$           100
# 3      5.0       bangladeshi   $$           173
# 4      5.0             delis    $           232
# 5      5.0             pizza    $           407
# 6      4.5             tacos    $          1099
# 7      5.0             halal    $           253
# 8      5.0            coffee   $$           339
# 9      5.0      cocktailbars   $$           157
# 10     5.0        sandwiches    $           165
# 11     5.0          desserts    $           146
# 12     5.0             cafes    $           222
# 13     4.5             tacos    $          2636
# 14     5.0     mediterranean   $$           206
# 15     5.0           italian   $$           275
# 16     4.5             delis    $           976
# 17     5.0        mideastern    $           210
# 18     5.0          japanese   $$           148
# 19     5.0             delis   $$           153
# 20     5.0            coffee    $            60
# 21     4.5   modern_european   $$           350
# 22     4.5             sushi  $$$           346
# 23     5.0          bakeries    $           184
# 24     5.0            coffee    $           160
# 25     4.5           spanish   $$           534
# 26     5.0             sushi  $$$           206
# 27     4.5           seafood    $           472
# 28     5.0  breakfast_brunch   $$            82
# 29     4.5             delis    $           486
# 30     4.5           mexican   $$           641
# 31     4.5            indpak   $$           276
# 32     4.5           afghani   $$           298
# 33     5.0             steak  $$$           194
# 34     4.5          desserts   $$           309
# 35     4.5            hotpot   $$           436
# 36     5.0          bakeries    $            94
# 37     5.0            coffee   $$            94
# 38     5.0            coffee    $            97
# 39     4.5        foodtrucks    $           350
# 40     4.5             meats    $           313
# 41     5.0           italian   $$            80
# 42     5.0           chinese   $$           131
# 43     5.0            coffee   $$           178
# 44     4.5             greek  $$$           318
# 45     5.0             cafes    $            75
# 46     4.5            coffee    $           644
# 47     4.5              thai   $$          1070
# 48     5.0             delis   $$            98
# 49     4.5         wine_bars   $$           186

# %%
#df_sort_ny = df_ny.sort_values(by=['rating'], ascending=False)
#df_sort_ny

# %%
df_sort_ny['address']=df_sort_ny['address'].str.replace('[', ' ').str.replace(']', '')

df_sort_ny
# Out:
#                              name  phone_number postal_code  \
# 0                            Otis  +16468860601       11206
# 17                    Pita Palace  +17183830550       11211
# 38                Kafe Louverture  +13473053176       11216
# 33            4 Charles Prime Rib  +12125615992       10014
# 41               Panzerotti Bites  +17184889300       11231
# 42                   Dian Kitchen  +16465909898       10009
# 28              191 Knickerbocker  +19293053625       11237
# 43            Three Seat Espresso  +19173882769       10009
# 26                      Sushi Lin  +13476276027       11217
# 1                      The Alcove  +13478134159       11104
# 24               Lella Alimentari  +17185992625       11211
# 23           Second Street Bakery  +12014201793       07302
# 45          Lillo Cucina Italiana  +13477630899       11201
# 20           Frenchy's Food Truck  +16464682861       11238
# 19         Tony's Beechhurst Deli  +17187678222       11357
# 36               Tres Leches Cafe  +16465590176       10029
# 18                  Samurai Sushi  +12018961760       07073
# 8                   Miscelanea NY  +12122530277       10003
# 15                 Non Solo Piada  +12122160616       10018
# 2                 Taste of Heaven  +17185763146       11211
# 3                   Korai Kitchen  +12017216566       07306
# 4                Andrea Salumeria  +12016531666       07307
# 5            L'industrie Pizzeria  +17185990002       11211
# 48             Joe's Italian Deli  +17183677979       10458
# 7          Royal Grill Halal Food  +13477240504       10036
# 37                     Griot Cafe  +12014209444       07307
# 9   Hold Fast Kitchen and Spirits  +19172616691       10036
# 10               Green Juice Cafe  +16469187730       10033
# 11                 Joey Bats Café  +12129511189       10002
# 12                     Cafe Talya  +12015355333       07002
# 14      Koroni Souvlaki and Grill  +17184898820       11102
# 44                 Loi Estiatorio  +12127130015       10019
# 40     Sorriso Italian Pork Store  +17187284392       11103
# 39                Mysttik Masaala  +19173063128       10022
# 47             Top Thai Greenwich  +16467264418       10012
# 46               Frisson Espresso  +16468503928       10036
# 25                    Casa d'Paco  +18623079466       07105
# 35                  Laojie Hotpot  +17184310026       11220
# 34        Aux Merveilleux De Fred  +19174751992       10014
# 32             Sami's Kabab House  +19178327165       11106
# 31                  Mughlai Grill  +12125332828       10002
# 30                         Jajaja  +16468835453       10002
# 29          Fiore Deli of Hoboken  +12016591655       07030
# 27                   Los Mariscos  +12129204986       10011
# 22      Sushi by Bou Times Square                     10036
# 21               Baba's Pierogies  +17182220777       11215
# 16    Sal, Kris, & Charlie's Deli  +17182789240       11105
# 13                 Los Tacos No.1  +12122560343       10011
# 6                  Los Tacos No.1  +12125744696       10036
# 49                        Ruffian                     10009
#
#                                               address             city  \
# 0              '18 Harrison Pl', 'Brooklyn, NY 11206'         Brooklyn
# 17             '413 Graham Ave', 'Brooklyn, NY 11211'         Brooklyn
# 38              '392 Halsey St', 'Brooklyn, NY 11216'         Brooklyn
# 33               '4 Charles St', 'New York, NY 10014'         New York
# 41               '235 Smith St', 'Brooklyn, NY 11231'         Brooklyn
# 42               '435 E 9th St', 'New York, NY 10009'         New York
# 28      '191 Knickerbocker Ave', 'Brooklyn, NY 11237'         Brooklyn
# 43               '137 Avenue A', 'New York, NY 10009'         New York
# 26           '335 Flatbush Ave', 'Brooklyn, NY 11217'         Brooklyn
# 1              '41-11 49th St', 'Sunnyside, NY 11104'        Sunnyside
# 24          '325 Manhattan Ave', 'Brooklyn, NY 11211'         Brooklyn
# 23              '402 2nd St', 'Jersey City, NJ 07302'      Jersey City
# 45               '331 Henry St', 'Brooklyn, NY 11201'         Brooklyn
# 20           '341 Eastern Pkwy', 'Brooklyn, NY 11238'         Brooklyn
# 19            '1118 154th St', 'Whitestone, NY 11357'       Whitestone
# 36             '356 E 112th St', 'New York, NY 10029'         New York
# 18        '254 Park Ave', 'East Rutherford, NJ 07073'  East Rutherford
# 8                 '63 E 4th St', 'New York, NY 10003'         New York
# 15              '302 W 37th St', 'New York, NY 10018'         New York
# 2              '251 Jackson St', 'Brooklyn, NY 11211'         Brooklyn
# 3           '576 Summit Ave', 'Jersey City, NJ 07306'      Jersey City
# 4    '247 Central Ave', 'Apt 3', 'Jersey City, NJ ...      Jersey City
# 5                '254 S 2nd St', 'Brooklyn, NY 11211'         Brooklyn
# 48                '685 E 187th St', 'Bronx, NY 10458'            Bronx
# 7         '44th St And 6th Ave', 'New York, NY 10036'         New York
# 37         '434 Central Ave', 'Jersey City, NJ 07307'      Jersey City
# 9                '364 W46th St', 'New York, NY 10036'         New York
# 10              '4316 Broadway', 'New York, NY 10033'         New York
# 11               '129 Allen St', 'New York, NY 10002'         New York
# 12                   '218 Ave B', 'Bayonne, NJ 07002'          Bayonne
# 14           '29-37 Newtown Ave', 'Astoria, NY 11102'          Astoria
# 44              '132 W 58th St', 'New York, NY 10019'         New York
# 40               '4416 30th Ave', 'Astoria, NY 11103'          Astoria
# 39   '399 Park Ave', 'Corner of 54th street', 'New...         New York
# 47            '235 Sullivan St', 'New York, NY 10012'         New York
# 46              '326 W 47th St', 'New York, NY 10036'         New York
# 25                '73 Warwick St', 'Newark, NJ 07105'           Newark
# 35                '811 53rd St', 'Brooklyn, NY 11220'         Brooklyn
# 34                 '37 8th Ave', 'New York, NY 10014'         New York
# 32           '35-57 Crescent St', 'Astoria, NY 11106'          Astoria
# 31               '6 Clinton St', 'New York, NY 10002'         New York
# 30             '162 E Broadway', 'New York, NY 10002'         New York
# 29                '414 Adams St', 'Hoboken, NJ 07030'          Hoboken
# 27              '409 W 15th St', 'New York, NY 10011'         New York
# 22              '132 W 47th St', 'New York, NY 10036'         New York
# 21                '295 3rd Ave', 'Brooklyn, NY 11215'         Brooklyn
# 16              '33-12 23rd Ave', 'Astoria, NY 11105'          Astoria
# 13                 '75 9th Ave', 'New York, NY 10011'         New York
# 6               '229 W 43rd St', 'New York, NY 10036'         New York
# 49               '125 E 7th St', 'New York, NY 10009'         New York
#
#     rating          category cost  review_Count
# 0      5.0       newamerican   $$           172
# 17     5.0        mideastern    $           210
# 38     5.0            coffee    $            97
# 33     5.0             steak  $$$           194
# 41     5.0           italian   $$            80
# 42     5.0           chinese   $$           131
# 28     5.0  breakfast_brunch   $$            82
# 43     5.0            coffee   $$           178
# 26     5.0             sushi  $$$           206
# 1      5.0        gastropubs   $$           677
# 24     5.0            coffee    $           160
# 23     5.0          bakeries    $           184
# 45     5.0             cafes    $            75
# 20     5.0            coffee    $            60
# 19     5.0             delis   $$           153
# 36     5.0          bakeries    $            94
# 18     5.0          japanese   $$           148
# 8      5.0            coffee   $$           339
# 15     5.0           italian   $$           275
# 2      5.0          soulfood   $$           100
# 3      5.0       bangladeshi   $$           173
# 4      5.0             delis    $           232
# 5      5.0             pizza    $           407
# 48     5.0             delis   $$            98
# 7      5.0             halal    $           253
# 37     5.0            coffee   $$            94
# 9      5.0      cocktailbars   $$           157
# 10     5.0        sandwiches    $           165
# 11     5.0          desserts    $           146
# 12     5.0             cafes    $           222
# 14     5.0     mediterranean   $$           206
# 44     4.5             greek  $$$           318
# 40     4.5             meats    $           313
# 39     4.5        foodtrucks    $           350
# 47     4.5              thai   $$          1070
# 46     4.5            coffee    $           644
# 25     4.5           spanish   $$           534
# 35     4.5            hotpot   $$           436
# 34     4.5          desserts   $$           309
# 32     4.5           afghani   $$           298
# 31     4.5            indpak   $$           276
# 30     4.5           mexican   $$           641
# 29     4.5             delis    $           486
# 27     4.5           seafood    $           472
# 22     4.5             sushi  $$$           346
# 21     4.5   modern_european   $$           350
# 16     4.5             delis    $           976
# 13     4.5             tacos    $          2636
# 6      4.5             tacos    $          1099
# 49     4.5         wine_bars   $$           186

# %%
df_sort_ny.phone_number=df_sort_ny.phone_number.str.replace("\+1", "")

df_sort_ny.head()
# Out:
#                    name phone_number postal_code  \
# 0                  Otis   6468860601       11206
# 17          Pita Palace   7183830550       11211
# 38      Kafe Louverture   3473053176       11216
# 33  4 Charles Prime Rib   2125615992       10014
# 41     Panzerotti Bites   7184889300       11231
#
#                                     address      city  rating     category  \
# 0    '18 Harrison Pl', 'Brooklyn, NY 11206'  Brooklyn     5.0  newamerican
# 17   '413 Graham Ave', 'Brooklyn, NY 11211'  Brooklyn     5.0   mideastern
# 38    '392 Halsey St', 'Brooklyn, NY 11216'  Brooklyn     5.0       coffee
# 33     '4 Charles St', 'New York, NY 10014'  New York     5.0        steak
# 41     '235 Smith St', 'Brooklyn, NY 11231'  Brooklyn     5.0      italian
#
#    cost  review_Count
# 0    $$           172
# 17    $           210
# 38    $            97
# 33  $$$           194
# 41   $$            80

# %%
#df_sort_ny['address'] = df_sort_ny['address'].replace(' ', '[')

#df_sort_ny.address = df_sort_ny.address.astype(str).replace('[', '')
df_sort_ny.head()
# Out:
#                    name phone_number postal_code  \
# 0                  Otis   6468860601       11206
# 17          Pita Palace   7183830550       11211
# 38      Kafe Louverture   3473053176       11216
# 33  4 Charles Prime Rib   2125615992       10014
# 41     Panzerotti Bites   7184889300       11231
#
#                                     address      city  rating     category  \
# 0    '18 Harrison Pl', 'Brooklyn, NY 11206'  Brooklyn     5.0  newamerican
# 17   '413 Graham Ave', 'Brooklyn, NY 11211'  Brooklyn     5.0   mideastern
# 38    '392 Halsey St', 'Brooklyn, NY 11216'  Brooklyn     5.0       coffee
# 33     '4 Charles St', 'New York, NY 10014'  New York     5.0        steak
# 41     '235 Smith St', 'Brooklyn, NY 11231'  Brooklyn     5.0      italian
#
#    cost  review_Count
# 0    $$           172
# 17    $           210
# 38    $            97
# 33  $$$           194
# 41   $$            80

# %%
df_sort_ny.reset_index(drop=True, inplace=True)
df_sort_ny
# Out:
#                              name phone_number postal_code  \
# 0                            Otis   6468860601       11206
# 1                     Pita Palace   7183830550       11211
# 2                 Kafe Louverture   3473053176       11216
# 3             4 Charles Prime Rib   2125615992       10014
# 4                Panzerotti Bites   7184889300       11231
# 5                    Dian Kitchen   6465909898       10009
# 6               191 Knickerbocker   9293053625       11237
# 7             Three Seat Espresso   9173882769       10009
# 8                       Sushi Lin   3476276027       11217
# 9                      The Alcove   3478134159       11104
# 10               Lella Alimentari   7185992625       11211
# 11           Second Street Bakery   2014201793       07302
# 12          Lillo Cucina Italiana   3477630899       11201
# 13           Frenchy's Food Truck   6464682861       11238
# 14         Tony's Beechhurst Deli   7187678222       11357
# 15               Tres Leches Cafe   6465590176       10029
# 16                  Samurai Sushi   2018961760       07073
# 17                  Miscelanea NY   2122530277       10003
# 18                 Non Solo Piada   2122160616       10018
# 19                Taste of Heaven   7185763146       11211
# 20                  Korai Kitchen   2017216566       07306
# 21               Andrea Salumeria   2016531666       07307
# 22           L'industrie Pizzeria   7185990002       11211
# 23             Joe's Italian Deli   7183677979       10458
# 24         Royal Grill Halal Food   3477240504       10036
# 25                     Griot Cafe   2014209444       07307
# 26  Hold Fast Kitchen and Spirits   9172616691       10036
# 27               Green Juice Cafe   6469187730       10033
# 28                 Joey Bats Café   2129511189       10002
# 29                     Cafe Talya   2015355333       07002
# 30      Koroni Souvlaki and Grill   7184898820       11102
# 31                 Loi Estiatorio   2127130015       10019
# 32     Sorriso Italian Pork Store   7187284392       11103
# 33                Mysttik Masaala   9173063128       10022
# 34             Top Thai Greenwich   6467264418       10012
# 35               Frisson Espresso   6468503928       10036
# 36                    Casa d'Paco   8623079466       07105
# 37                  Laojie Hotpot   7184310026       11220
# 38        Aux Merveilleux De Fred   9174751992       10014
# 39             Sami's Kabab House   9178327165       11106
# 40                  Mughlai Grill   2125332828       10002
# 41                         Jajaja   6468835453       10002
# 42          Fiore Deli of Hoboken   2016591655       07030
# 43                   Los Mariscos   2129204986       10011
# 44      Sushi by Bou Times Square                    10036
# 45               Baba's Pierogies   7182220777       11215
# 46    Sal, Kris, & Charlie's Deli   7182789240       11105
# 47                 Los Tacos No.1   2122560343       10011
# 48                 Los Tacos No.1   2125744696       10036
# 49                        Ruffian                    10009
#
#                                               address             city  \
# 0              '18 Harrison Pl', 'Brooklyn, NY 11206'         Brooklyn
# 1              '413 Graham Ave', 'Brooklyn, NY 11211'         Brooklyn
# 2               '392 Halsey St', 'Brooklyn, NY 11216'         Brooklyn
# 3                '4 Charles St', 'New York, NY 10014'         New York
# 4                '235 Smith St', 'Brooklyn, NY 11231'         Brooklyn
# 5                '435 E 9th St', 'New York, NY 10009'         New York
# 6       '191 Knickerbocker Ave', 'Brooklyn, NY 11237'         Brooklyn
# 7                '137 Avenue A', 'New York, NY 10009'         New York
# 8            '335 Flatbush Ave', 'Brooklyn, NY 11217'         Brooklyn
# 9              '41-11 49th St', 'Sunnyside, NY 11104'        Sunnyside
# 10          '325 Manhattan Ave', 'Brooklyn, NY 11211'         Brooklyn
# 11              '402 2nd St', 'Jersey City, NJ 07302'      Jersey City
# 12               '331 Henry St', 'Brooklyn, NY 11201'         Brooklyn
# 13           '341 Eastern Pkwy', 'Brooklyn, NY 11238'         Brooklyn
# 14            '1118 154th St', 'Whitestone, NY 11357'       Whitestone
# 15             '356 E 112th St', 'New York, NY 10029'         New York
# 16        '254 Park Ave', 'East Rutherford, NJ 07073'  East Rutherford
# 17                '63 E 4th St', 'New York, NY 10003'         New York
# 18              '302 W 37th St', 'New York, NY 10018'         New York
# 19             '251 Jackson St', 'Brooklyn, NY 11211'         Brooklyn
# 20          '576 Summit Ave', 'Jersey City, NJ 07306'      Jersey City
# 21   '247 Central Ave', 'Apt 3', 'Jersey City, NJ ...      Jersey City
# 22               '254 S 2nd St', 'Brooklyn, NY 11211'         Brooklyn
# 23                '685 E 187th St', 'Bronx, NY 10458'            Bronx
# 24        '44th St And 6th Ave', 'New York, NY 10036'         New York
# 25         '434 Central Ave', 'Jersey City, NJ 07307'      Jersey City
# 26               '364 W46th St', 'New York, NY 10036'         New York
# 27              '4316 Broadway', 'New York, NY 10033'         New York
# 28               '129 Allen St', 'New York, NY 10002'         New York
# 29                   '218 Ave B', 'Bayonne, NJ 07002'          Bayonne
# 30           '29-37 Newtown Ave', 'Astoria, NY 11102'          Astoria
# 31              '132 W 58th St', 'New York, NY 10019'         New York
# 32               '4416 30th Ave', 'Astoria, NY 11103'          Astoria
# 33   '399 Park Ave', 'Corner of 54th street', 'New...         New York
# 34            '235 Sullivan St', 'New York, NY 10012'         New York
# 35              '326 W 47th St', 'New York, NY 10036'         New York
# 36                '73 Warwick St', 'Newark, NJ 07105'           Newark
# 37                '811 53rd St', 'Brooklyn, NY 11220'         Brooklyn
# 38                 '37 8th Ave', 'New York, NY 10014'         New York
# 39           '35-57 Crescent St', 'Astoria, NY 11106'          Astoria
# 40               '6 Clinton St', 'New York, NY 10002'         New York
# 41             '162 E Broadway', 'New York, NY 10002'         New York
# 42                '414 Adams St', 'Hoboken, NJ 07030'          Hoboken
# 43              '409 W 15th St', 'New York, NY 10011'         New York
# 44              '132 W 47th St', 'New York, NY 10036'         New York
# 45                '295 3rd Ave', 'Brooklyn, NY 11215'         Brooklyn
# 46              '33-12 23rd Ave', 'Astoria, NY 11105'          Astoria
# 47                 '75 9th Ave', 'New York, NY 10011'         New York
# 48              '229 W 43rd St', 'New York, NY 10036'         New York
# 49               '125 E 7th St', 'New York, NY 10009'         New York
#
#     rating          category cost  review_Count
# 0      5.0       newamerican   $$           172
# 1      5.0        mideastern    $           210
# 2      5.0            coffee    $            97
# 3      5.0             steak  $$$           194
# 4      5.0           italian   $$            80
# 5      5.0           chinese   $$           131
# 6      5.0  breakfast_brunch   $$            82
# 7      5.0            coffee   $$           178
# 8      5.0             sushi  $$$           206
# 9      5.0        gastropubs   $$           677
# 10     5.0            coffee    $           160
# 11     5.0          bakeries    $           184
# 12     5.0             cafes    $            75
# 13     5.0            coffee    $            60
# 14     5.0             delis   $$           153
# 15     5.0          bakeries    $            94
# 16     5.0          japanese   $$           148
# 17     5.0            coffee   $$           339
# 18     5.0           italian   $$           275
# 19     5.0          soulfood   $$           100
# 20     5.0       bangladeshi   $$           173
# 21     5.0             delis    $           232
# 22     5.0             pizza    $           407
# 23     5.0             delis   $$            98
# 24     5.0             halal    $           253
# 25     5.0            coffee   $$            94
# 26     5.0      cocktailbars   $$           157
# 27     5.0        sandwiches    $           165
# 28     5.0          desserts    $           146
# 29     5.0             cafes    $           222
# 30     5.0     mediterranean   $$           206
# 31     4.5             greek  $$$           318
# 32     4.5             meats    $           313
# 33     4.5        foodtrucks    $           350
# 34     4.5              thai   $$          1070
# 35     4.5            coffee    $           644
# 36     4.5           spanish   $$           534
# 37     4.5            hotpot   $$           436
# 38     4.5          desserts   $$           309
# 39     4.5           afghani   $$           298
# 40     4.5            indpak   $$           276
# 41     4.5           mexican   $$           641
# 42     4.5             delis    $           486
# 43     4.5           seafood    $           472
# 44     4.5             sushi  $$$           346
# 45     4.5   modern_european   $$           350
# 46     4.5             delis    $           976
# 47     4.5             tacos    $          2636
# 48     4.5             tacos    $          1099
# 49     4.5         wine_bars   $$           186

# %%
#Save to a CSV all data retrieved
df_sort_ny.to_csv("NewYork.csv", sep=',',index=False)

# %% [markdown]
# # Read Into Database

# %%
import pymysql
pymysql.install_as_MySQLdb()

from sqlalchemy import create_engine
#engine = create_engine("mysql://USER:PASSWORD@HOST/DATABASE")
engine = create_engine("mysql://root:root123@localhost/restaurant_review")

# %%
df_sort_ny.dtypes
#df_sort_ny.dtypes
# Out:
# name             object
# phone_number     object
# postal_code      object
# address          object
# city             object
# rating          float64
# category         object
# cost             object
# review_Count      int64
# dtype: object

# %%
#df_sort_ny.to_sql(
df_sort_ny.to_sql(
                name='yelp',
                con=engine, 
                if_exists="append"
                 )
