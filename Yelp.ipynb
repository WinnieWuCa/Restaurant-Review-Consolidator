# %%
# Project 2 - Yelp API

# %%
# !pip install yelpapi

# %%
# Dependencies and Setup
import requests
import json
import pandas as pd

# Import API key
from api_keys import api_key

# %%
api_key='QWMy8-jFwxoKJkLNvzLl-jDymYjp-bN83izdcDMb91a3JG5h_8XRcjYNWWSXYhKjo0cPdnC_UdrnlAaap6kwUqa3Cqm2dCU202lvbXL3AkUqJ_m7PQAFKlqnvmGyXHYx'

headers = {'Authorization': 'Bearer %s' % api_key}

# %%
url='https://api.yelp.com/v3/businesses/search'

# %% [markdown]
# # 1) Toronto

# %%
# Perform API Calls - test with one restaurant 

params_to = {'term':'restaurant',
     'location':'Toronto', 
     'sort_by': 'rating',        
     'limit':'50'}

# %%
request=requests.get(url, params=params_to, headers=headers)
print('The status code is {}'.format(request.status_code))
# Out:
# The status code is 200

# %%
#Convert the data into a JSON object
parsed_to = json.loads(request.text)
toronto = parsed_to["businesses"]

# %%
#“businesses” is a list, enclosed by a square brackets.
# extract businesses first into a Python list and then loop over the businesses in the list.
# count = 1
name = []
phone_number = []
postal_code =[]
address = []
city = []
rating = []
category = []
cost = []
review_count = []
 

for business in toronto:
    #print("Number:", count)
    #print("Name:", business["name"])
    #print("Address:", " ".join(business["location"]["display_address"]))
    #print("City:", " ".join(business["location"]["city"]))
    #print("Rating:", business["rating"])
    #print("Category:", business["categories"][0].get('alias'))
        
    #if 'price' in business:
    #    print("Cost:", business["price"])
    #
    #print("\n")
    #print("Review Count:", business["review_count"])
    
    name.append(business["name"])
    phone_number.append(business["phone"])        
    postal_code.append(business["location"]["zip_code"])
    address.append(business["location"]["display_address"])
    city.append(business["location"]["city"])
    rating.append(business["rating"])
    category.append(business["categories"][0].get('alias'))
    
    
    if 'price' in business:
        cost.append(business["price"])
    else:
        cost.append("")
    review_count.append(business["review_count"])

    # count = count+1

# %%
#Display the DataFrame

#Display the DataFrame
df_to = pd.DataFrame(data={"name": name, "phone_number": phone_number,"postal_code": postal_code, "address": address, "city": city, "rating":
                       rating, "category": category, "cost": cost, "review_Count": review_count})

df_sort_to = df_to.sort_values(by=['rating'], ascending=False)
df_sort_to
# Out:
#                                         name  phone_number postal_code  \
# 0                              Baretto Caffe  +14163850003     M3B 2W7
# 4                                     Veghed  +14168416673     M6J 1X3
# 45                        Momo Hut & Gardens  +14163638580     M4K 1P1
# 38                        I'll Be Seeing You  +14167789988     M4M 1H3
# 35                                Ravi Soups  +16474358365     M5V 1R1
# 27                                      Sugo  +14165351717     M6H 3Y2
# 28                               Riddle Room  +16473442637     M4Y 1Z2
# 29                     Beach Hill Smokehouse  +14167928275     M4E 2W1
# 30                            Takht-e Tavoos  +16473527322     M6H 1B5
# 31                                      Rasa  +16473508221     M5S 2K8
# 32                              Saigon Lotus  +14169011115     M5T 1K6
# 33                            Veggie D'Light  +16473527581     M5T 3K7
# ...

# %%
#Save to a CSV all data retrieved
df_sort_to.to_csv("Toronto.csv", sep=',',index=False)
#df_to.to_csv("Toronto.csv", sep=',',index=False)

# %% [markdown]
# # 2) New York

# %%
# Perform API Calls - test with one restaurant 

params_ny = {'term':'restaurant',
     'location':'New York', 
     'sort_by': 'rating',        
     'limit':'50'}

# %%
request=requests.get(url, params=params_ny, headers=headers)
print('The status code is {}'.format(request.status_code))
# Out:
# The status code is 200

# %%
#Convert the data into a JSON object
parsed_ny = json.loads(request.text)
newyork = parsed_ny["businesses"]

# %%
#print parsed to get an idea how it looks like
#print(json.dumps(parsed_ny, indent=4))

# %%
#“businesses” is a list, enclosed by a square brackets.
# extract businesses first into a Python list and then loop over the businesses in the list.
# count = 1
name = []
phone_number = []
postal_code =[]
address = []
city = []
rating = []
category = []
cost = []
review_count = []
 

for business in newyork:
    #print("Number:", count)
    #print("Name:", business["name"])
    #print("Address:", " ".join(business["location"]["display_address"]))
    #print("City:", " ".join(business["location"]["city"]))
    #print("Rating:", business["rating"])
    #print("Category:", business["categories"][0].get('alias'))
        
    #if 'price' in business:
    #    print("Cost:", business["price"])
    #
    #print("\n")
    #print("Review Count:", business["review_count"])
    
    name.append(business["name"])
    phone_number.append(business["phone"])        
    postal_code.append(business["location"]["zip_code"])
    address.append(business["location"]["display_address"])
    city.append(business["location"]["city"])
    rating.append(business["rating"])
    category.append(business["categories"][0].get('alias'))
    
    
    if 'price' in business:
        cost.append(business["price"])
    else:
        cost.append("")
    review_count.append(business["review_count"])

    # count = count+1

# %%
#Display the DataFrame
df_ny = pd.DataFrame(data={"name": name, "phone_number": phone_number,"postal_code": postal_code, "address": address, "city": city, "rating":
                       rating, "category": category, "cost": cost, "review_Count": review_count})

df_sort_ny = df_ny.sort_values(by=['rating'], ascending=False)
df_sort_ny
# Out:
#                              name  phone_number postal_code  \
# 0                            Otis  +16468860601       11206
# 17                    Pita Palace  +17183830550       11211
# 38                Kafe Louverture  +13473053176       11216
# 33            4 Charles Prime Rib  +12125615992       10014
# 41               Panzerotti Bites  +17184889300       11231
# 42                   Dian Kitchen  +16465909898       10009
# 28              191 Knickerbocker  +19293053625       11237
# 43            Three Seat Espresso  +19173882769       10009
# 26                      Sushi Lin  +13476276027       11217
# 1                      The Alcove  +13478134159       11104
# 24               Lella Alimentari  +17185992625       11211
# 23           Second Street Bakery  +12014201793       07302
# 45          Lillo Cucina Italiana  +13477630899       11201
# 20           Frenchy's Food Truck  +16464682861       11238
# 19         Tony's Beechhurst Deli  +17187678222       11357
# ...

# %%
#Save to a CSV all data retrieved
df_sort_ny.to_csv("NewYork.csv", sep=',',index=False)
#df_ny.to_csv("NewYork.csv", sep=',',index=False)

# %% [markdown]
# # 3) London

# %%
# Perform API Calls - test with one restaurant 
params_ld = {'term':'restaurant',
             'location':'London', 
             'sort_by': 'rating',    
             'limit':'50'}

# %%
request=requests.get(url, params=params_ld, headers=headers)
print('The status code is {}'.format(request.status_code))
# Out:
# The status code is 200

# %%
#Convert the data into a JSON object
parsed_ld = json.loads(request.text)
london = parsed_ld["businesses"]

# %%
#“businesses” is a list, enclosed by a square brackets.
# extract businesses first into a Python list and then loop over the businesses in the list.
# count = 1
name = []
phone_number = []
postal_code =[]
address = []
city = []
rating = []
category = []
cost = []
review_count = []
 

for business in london:
    #print("Number:", count)
    #print("Name:", business["name"])
    #print("Address:", " ".join(business["location"]["display_address"]))
    #print("City:", " ".join(business["location"]["city"]))
    #print("Rating:", business["rating"])
    #print("Category:", business["categories"][0].get('alias'))
        
    #if 'price' in business:
    #    print("Cost:", business["price"])
    #
    #print("\n")
    #print("Review Count:", business["review_count"])
    
    name.append(business["name"])
    phone_number.append(business["phone"])        
    postal_code.append(business["location"]["zip_code"])
    address.append(business["location"]["display_address"])
    city.append(business["location"]["city"])
    rating.append(business["rating"])
    category.append(business["categories"][0].get('alias'))
    
    
    if 'price' in business:
        cost.append(business["price"])
    else:
        cost.append("")
    review_count.append(business["review_count"])

    # count = count+1

# %%
#Display the DataFrame
#Display the DataFrame
df_ld = pd.DataFrame(data={"name": name, "phone_number": phone_number,"postal_code": postal_code, "address": address, "city": city, "rating":
                       rating, "category": category, "cost": cost, "review_Count": review_count})

df_sort_ld = df_ld.sort_values(by=['rating'], ascending=False)
df_sort_ld
# Out:
#                            name   phone_number postal_code  \
# 0             The Golden Chippy  +442086924333    SE10 8LF
# 4          Kennington Lane Cafe  +442077355853    SE11 5QY
# 20                   Il Portico  +442076026262      W8 6NA
# 16                     Bageriet  +442072400000    WC2E 9EA
# 35   The Tiroler Hut Restaurant  +442077273981      W2 4UA
# 27                 The Fat Bear  +442072362498    EC4V 5DY
# 28                 Ozone Coffee  +442074901039    EC2A 4AQ
# 29                    Barrafina  +442074401456    WC2N 4HZ
# 30                Pimlico Fresh  +442079320030    SW1V 1DE
# 31            Quilon Restaurant  +442078211899    SW1E 6AF
# 32                 Franco Manca  +442077383021     SW9 8LD
# 33                      Goodman  +442074993776     W1S 1QH
# 34                    Kanada-Ya  +442072400232    WC2H 8LE
# 36                    Blacklock  +442034416996     W1D 7LG
# 1           Ffiona's Restaurant  +442079374152      W8 4BA
# ...

# %%
#Save to a CSV all data retrieved
df_sort_ld.to_csv("London.csv", sep=',',index=False)
#df_ld.to_csv("London.csv", sep=',',index=False)

# %% [markdown]
# # 4) Paris

# %%
# Perform API Calls - test with one restaurant 
params_ps = {'term':'restaurant',
             'location':'Paris', 
             'sort_by': 'rating',  
             'limit':50}

# %%
request=requests.get(url, params=params_ps, headers=headers)
print('The status code is {}'.format(request.status_code))
# Out:
# The status code is 200

# %%
#Convert the data into a JSON object
parsed_ps = json.loads(request.text)
paris = parsed_ps["businesses"]

# %%
#“businesses” is a list, enclosed by a square brackets.
# extract businesses first into a Python list and then loop over the businesses in the list.
# count = 1
name = []
phone_number = []
postal_code =[]
address = []
city = []
rating = []
category = []
cost = []
review_count = []
 

for business in paris:
    #print("Number:", count)
    #print("Name:", business["name"])
    #print("Address:", " ".join(business["location"]["display_address"]))
    #print("City:", " ".join(business["location"]["city"]))
    #print("Rating:", business["rating"])
    #print("Category:", business["categories"][0].get('alias'))
        
    #if 'price' in business:
    #    print("Cost:", business["price"])
    #
    #print("\n")
    #print("Review Count:", business["review_count"])
    
    name.append(business["name"])
    phone_number.append(business["phone"])        
    postal_code.append(business["location"]["zip_code"])
    address.append(business["location"]["display_address"])
    city.append(business["location"]["city"])
    rating.append(business["rating"])
    category.append(business["categories"][0].get('alias'))
    
    
    if 'price' in business:
        cost.append(business["price"])
    else:
        cost.append("")
    review_count.append(business["review_count"])

    # count = count+1

# %%
#Display dataframe
#Display the DataFrame
df_ps = pd.DataFrame(data={"name": name, "phone_number": phone_number,"postal_code": postal_code, "address": address, "city": city, "rating":
                       rating, "category": category, "cost": cost, "review_Count": review_count})

df_sort_ps = df_ps.sort_values(by=['rating'], ascending=False)
df_sort_ps
# Out:
#                              name  phone_number postal_code  \
# 31              Reed - Restaurant  +33145558840       75007
# 33           Bar Italia Brasserie  +33183972585       75009
# 41                    L'Estrapade  +33143257258       75005
# 14       La Vache et le Cuisinier  +33142622215       75018
# 0      Le Potager du Père Thierry  +33153282620       75018
# 37            Le Jardin d'en Face  +33153280075       75018
# 28                 La Cordonnerie  +33142601742       75001
# 29           Le Temps des Cerises  +33142720863       75004
# 30           The Hardware Société  +33142516903       75018
# 32                   Les Papilles  +33143252079       75005
# 34                    La Jacobine  +33146341595       75006
# 35                     L'Alsacien  +33142776422       75004
# 36            Matamata Coffee Bar  +33171394458       75002
# 38                   Sacrée Fleur  +33142516618       75018
# 26               L'As du Fallafel  +33148876360       75004
# ...

# %%
#Save to a CSV all data retrieved
df_sort_ps.to_csv("Paris.csv", sep=',',index=False)
#df_ps.to_csv("Paris.csv", sep=',',index=False)

# %% [markdown]
# # 5) Tokyo

# %%
# Perform API Calls - test with one restaurant 
params_tk = {'term':'restaurant',
             'location':'Tokyo', 
             'sort_by': 'rating',    
             'limit':'50'}

# %%
request=requests.get(url, params=params_tk, headers=headers)
print('The status code is {}'.format(request.status_code))
# Out:
# The status code is 200

# %%
#Convert the data into a JSON object
parsed_tk = json.loads(request.text)
tokyo = parsed_tk["businesses"]

# %%
#“businesses” is a list, enclosed by a square brackets.
# extract businesses first into a Python list and then loop over the businesses in the list.
# count = 1
name = []
phone_number = []
postal_code =[]
address = []
city = []
rating = []
category = []
cost = []
review_count = []
 

for business in tokyo:
    #print("Number:", count)
    #print("Name:", business["name"])
    #print("Address:", " ".join(business["location"]["display_address"]))
    #print("City:", " ".join(business["location"]["city"]))
    #print("Rating:", business["rating"])
    #print("Category:", business["categories"][0].get('alias'))
        
    #if 'price' in business:
    #    print("Cost:", business["price"])
    #
    #print("\n")
    #print("Review Count:", business["review_count"])
    
    name.append(business["name"])
    phone_number.append(business["phone"])        
    postal_code.append(business["location"]["zip_code"])
    address.append(business["location"]["display_address"])
    city.append(business["location"]["city"])
    rating.append(business["rating"])
    category.append(business["categories"][0].get('alias'))
    
    
    if 'price' in business:
        cost.append(business["price"])
    else:
        cost.append("")
    review_count.append(business["review_count"])

    # count = count+1

# %%
#Display the DataFrame
#Display the DataFrame
df_tk = pd.DataFrame(data={"name": name, "phone_number": phone_number,"postal_code": postal_code, "address": address, "city": city, "rating":
                       rating, "category": category, "cost": cost, "review_Count": review_count})

df_sort_tk = df_tk.sort_values(by=['rating'], ascending=False)
df_sort_tk
# Out:
#                                                  name   phone_number  \
# 31                                              Ibuki   +81353233552
# 22                          Ichiran Shibuya Spainzaka   +81334640787
# 40                                              Gomei   +81368917711
# 3                                       Sushisho Masa   +81334999178
# 4              Uogashi Nihon Ichi Shinjuku Nishiguchi   +81333491739
# 5                                             Hakushu   +81334610546
# 16                             Sapporo DOMINICA Ginza   +81332311347
# 46                                       Manten Sushi   +81362699100
# 1              Gyukatsu MOTOMURA Tokyo Eki Yaesuguchi   +81332310337
# 37                            Tokyo Shiba Tofuya Ukai   +81334361028
# 10                                      AKIBA FUKUROU  +818034003511
# 11                         Gyukatsu Motomura Shinjuku   +81333540171
# 43                             Umai Sushi Kan Akasaka   +81335606711
# ...

# %%
#Save to a CSV all data retrieved
df_sort_tk.to_csv("Tokyo.csv", sep=',',index=False)
#df_tk.to_csv("Tokyo.csv", sep=',',index=False)

# %% [markdown]
# # Read Into Database

# %%
import pymysql
pymysql.install_as_MySQLdb()

from sqlalchemy import create_engine
#engine = create_engine("mysql://USER:PASSWORD@HOST/DATABASE")
engine = create_engine("mysql://root:root123@localhost/restaurant_review")

# %%
df_sort_ny.to_sql(
                name='yelp',
                con=engine,
                index= False,
                if_exists="append"
                 )

# %%
df_sort_ld.to_sql(
                name='yelp',
                con=engine,
                index= False,
                if_exists="append"
                 )

# %%
df_sort_ps.to_sql(
                name='yelp',
                con=engine,
                index=False,
                if_exists="append"
                 )

# %%
df_sort_tk.to_sql(
                name='yelp',
                con=engine,
                index=False,
                if_exists="append"
                 )
