# %%
# Project 2 - Yelp API

# %%
# !pip install yelpapi
# Out:
# Requirement already satisfied: yelpapi in /anaconda3/lib/python3.7/site-packages (2.3.0)
# Requirement already satisfied: requests in /anaconda3/lib/python3.7/site-packages (from yelpapi) (2.21.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /anaconda3/lib/python3.7/site-packages (from requests->yelpapi) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /anaconda3/lib/python3.7/site-packages (from requests->yelpapi) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda3/lib/python3.7/site-packages (from requests->yelpapi) (2018.11.29)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /anaconda3/lib/python3.7/site-packages (from requests->yelpapi) (1.24.1)

# %%
# Dependencies and Setup
import requests
import json
# Import API key
from api_keys import api_key

#----
import pandas as pd
import time
import pprint  
import datetime

# %%
api_key='QWMy8-jFwxoKJkLNvzLl-jDymYjp-bN83izdcDMb91a3JG5h_8XRcjYNWWSXYhKjo0cPdnC_UdrnlAaap6kwUqa3Cqm2dCU202lvbXL3AkUqJ_m7PQAFKlqnvmGyXHYx'

headers = {'Authorization': 'Bearer %s' % api_key}

# %%
url='https://api.yelp.com/v3/businesses/search'

# %% [markdown]
# # 1) Toronto

# %%
# Perform API Calls - test with one restaurant 

params_to = {'term':'restaurant',
     'location':'Toronto', 
     'sort_by': 'rating',        
     'limit':'50'}

# %%
request=requests.get(url, params=params_to, headers=headers)
print('The status code is {}'.format(request.status_code))
# Out:
# The status code is 200

# %%
#Convert the data into a JSON object
parsed_to = json.loads(request.text)
toronto = parsed_to["businesses"]

# %%
#“businesses” is a list, enclosed by a square brackets.
# extract businesses first into a Python list and then loop over the businesses in the list.
count = 1
name = []
address = []
city = []
stars = []
category = []
cost = []
review_count = []

for business in toronto:
    #print("Number:", count)
    #print("Name:", business["name"])
    #print("Address:", " ".join(business["location"]["display_address"]))
    #print("City:", " ".join(business["location"]["city"]))
    #print("Rating:", business["rating"])
    #print("Category:", business["categories"])
        
    #if 'price' in business:
    #    print("Cost:", business["price"])
    #
    #print("\n")
    #print("Review Count:", business["review_count"])
    
    name.append(business["name"])
    address.append(business["location"]["display_address"])
    city.append(business["location"]["city"])
    stars.append(business["rating"])
    category.append(business["categories"])
    
    if 'price' in business:
        cost.append(business["price"])
    else:
        cost.append("")
    review_count.append(business["review_count"])

    count = count+1

# %%
#Display the DataFrame

df_to = pd.DataFrame(data={"Restaurant Name": name, "Restaurant Address": address, "Restaurant City": city, "Stars":
                       stars, "Category": category, "Cost": cost, "Review Count": review_count})
df_to
#df_sort_ny = df_ny.sort_values(by=['Review Count'], ascending=False)
#df_sort_ny
# Out:
#                              Restaurant Name  \
# 0                              Baretto Caffe
# 1                                       Yasu
# 2                             Alo Restaurant
# 3                    Blaze Fast-Fire'd Pizza
# 4                                     Veghed
# 5                    Jacobs & Co. Steakhouse
# 6                                  El Nahual
# 7               Seven Lives Tacos Y Mariscos
# 8                           Richmond Station
# 9                  Pai Northern Thai Kitchen
# 10                             Mystic Muffin
# 11                                    Byblos
# 12  Scaramouche Restaurant Pasta Bar & Grill
# 13          Her Father's Cider Bar & Kitchen
# 14                          Adamson Barbecue
# 15                      Antler Kitchen & Bar
# 16                                      Agio
# 17                              Ramen Isshin
# 18                               A-Game Cafe
# 19            Descendant Detroit Style Pizza
# 20                     Fresco's Fish & Chips
# 21                              Café Polonez
# 22                           Schnitzel Queen
# 23                              Banh Mi Boys
# 24                             Tibet Kitchen
# 25                                  Crepe TO
# 26                                   Katsuya
# 27                                      Sugo
# 28                               Riddle Room
# 29                     Beach Hill Smokehouse
# 30                            Takht-e Tavoos
# 31                                      Rasa
# 32                            Veggie D'Light
# 33                              Saigon Lotus
# 34                         Salus Fresh Foods
# 35                                Ravi Soups
# 36                                Le Baratin
# 37                               Black Camel
# 38                        I'll Be Seeing You
# 39                             Loga's Corner
# 40                                      Miku
# 41                            The Olde Yorke
# 42                    COO Café Bread or Rice
# 43                              Pow Wow Cafe
# 44                    KINKA IZAKAYA ORIGINAL
# 45                       Rustle & Still Café
# 46                               Nuit Social
# 47                                    George
# 48                                Hodo Kwaja
# 49                        Momo Hut & Gardens
#
#                                    Restaurant Address Restaurant City  Stars  \
# 0   [1262 Don Mills Road, Toronto, ON M3B 2W7, Can...         Toronto    5.0
# 1        [81 Harbord Street, Toronto, ON M5S, Canada]         Toronto    4.5
# 2   [163 Spadina Avenue, 3rd Floor, Toronto, ON M5...         Toronto    4.5
# 3   [10 Dundas Street East, #124, Toronto, ON M5B ...         Toronto    4.5
# 4   [1199 Dundas Street W, Toronto, ON M6J 1X3, Ca...         Toronto    5.0
# 5      [12 Brant Street, Toronto, ON M5V 1K4, Canada]         Toronto    4.5
# 6       [1993 Keele Street, York, ON M6M 3Y3, Canada]            York    4.5
# 7   [69 Kensington Avenue, Toronto, ON M5T 2K2, Ca...         Toronto    4.5
# 8   [1 Richmond Street W, Toronto, ON M5H 3W4, Can...         Toronto    4.5
# 9     [18 Duncan Street, Toronto, ON M5H 3G8, Canada]         Toronto    4.5
# 10   [113 Jarvis Street, Toronto, ON M5C 2H4, Canada]         Toronto    4.5
# 11    [11 Duncan Street, Toronto, ON M5V 3M2, Canada]         Toronto    4.5
# 12   [1 Benvenuto Place, Toronto, ON M4V 2L1, Canada]         Toronto    4.5
# 13  [119 Harbord Street, Toronto, ON M5S 1G7, Canada]         Toronto    4.5
# 14  [176 Wicksteed Avenue, Toronto, ON M4G 2B6, Ca...         Toronto    4.5
# 15  [1454 Dundas Street West, Toronto, ON M6J 1Y6,...         Toronto    4.5
# 16  [1351 St Clair Avenue W, Toronto, ON M6E 1C5, ...         Toronto    4.5
# 17  [421 College Street, Toronto, ON M5T 1T1, Canada]         Toronto    4.5
# 18  [797 Dundas Street W, Toronto, ON M6J 1V2, Can...         Toronto    4.5
# 19  [1168 Queen Street E, Toronto, ON M4M 1L5, Can...         Toronto    4.5
# 20  [201 Augusta Avenue, Toronto, ON M5T 2L4, Canada]         Toronto    4.5
# 21  [195 Roncesvalles Avenue, Toronto, ON M6R 2L5,...         Toronto    4.5
# 22  [211 Queen Street E, Toronto, ON M5A 1S5, Canada]         Toronto    4.5
# 23  [392 Queen Street W, Toronto, ON M5V 2A9, Canada]         Toronto    4.5
# 24  [1544 Queen Street W, Toronto, ON M6R 1A6, Can...         Toronto    4.5
# 25    [52 Church Street, Toronto, ON M5C 3C8, Canada]         Toronto    4.5
# 26  [66 Gerrard Street E, Unit 100, Toronto, ON M5...         Toronto    4.5
# 27  [1279 Bloor Street  W, Toronto, ON M6H 3Y2, Ca...         Toronto    4.5
# 28  [579 Yonge Street, 2nd Floor, Toronto, ON M4Y ...         Toronto    4.5
# 29   [172 Main Street S, Toronto, ON M4E 2W1, Canada]         Toronto    4.5
# 30  [1120 College Street, Toronto, ON M6H 1B5, Can...         Toronto    4.5
# 31   [196 Robert Street, Toronto, ON M5S 2K8, Canada]         Toronto    4.5
# 32  [160 Baldwin Street, Unit 3, Toronto, ON M5T 3...         Toronto    4.5
# 33  [6 St Andrew Street, Toronto, ON M5T 1K6, Canada]         Toronto    4.5
# 34  [25 Carlton Street, Unit D, Toronto, ON M5B 1L...         Toronto    4.5
# 35  [322 Adelaide Street W, Toronto, ON M5V 1R1, C...         Toronto    4.5
# 36  [1600 Dundas Street. W, Toronto, ON M6K 1T8, C...         Toronto    4.5
# 37     [4 Crescent Road, Toronto, ON M4W 1S9, Canada]         Toronto    4.5
# 38  [747 Queen Street E, Toronto, ON M4M 1H3, Canada]         Toronto    5.0
# 39   [216C Close Avenue, Toronto, ON M6K 2V5, Canada]         Toronto    4.5
# 40   [105-10 Bay Street, Toronto, ON M5J 2R8, Canada]         Toronto    4.0
# 41    [96 Laird Drive, East York, ON M4G 3V3, Canada]       East York    4.5
# 42  [1049 Bloor Street W, Toronto, ON M6H 1M4, Can...         Toronto    4.5
# 43  [213 Augusta Avenue, Toronto, ON M5T 2L4, Canada]         Toronto    4.5
# 44       [398 Church St, Toronto, ON M5B 2A2, Canada]         Toronto    4.0
# 45  [605 Bloor Street W, Toronto, ON M6G 1K6, Canada]         Toronto    4.5
# 46  [1168 Queen Street W, Toronto, ON M6J 1J5, Can...         Toronto    4.5
# 47  [111 Queen Street E, Toronto, ON M5C 1S2, Canada]         Toronto    4.5
# 48  [656 Bloor Street W, Toronto, ON M6G 1K9, Canada]         Toronto    4.5
# 49  [401 Danforth Avenue, Danforth, Toronto, ON M4...         Toronto    5.0
#
#                                              Category  Cost  Review Count
# 0   [{'alias': 'cafes', 'title': 'Cafes'}, {'alias...     $           293
# 1   [{'alias': 'japanese', 'title': 'Japanese'}, {...  $$$$           328
# 2   [{'alias': 'bars', 'title': 'Bars'}, {'alias':...  $$$$           250
# 3   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...    $$           467
# 4   [{'alias': 'vegan', 'title': 'Vegan'}, {'alias...    $$            60
# 5        [{'alias': 'steak', 'title': 'Steakhouses'}]  $$$$           507
# 6   [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     $            99
# 7          [{'alias': 'mexican', 'title': 'Mexican'}]     $          1215
# 8   [{'alias': 'newcanadian', 'title': 'Canadian (...   $$$           676
# 9                [{'alias': 'thai', 'title': 'Thai'}]    $$          2360
# 10  [{'alias': 'sandwiches', 'title': 'Sandwiches'...     $           249
# 11  [{'alias': 'mediterranean', 'title': 'Mediterr...   $$$           740
# 12  [{'alias': 'french', 'title': 'French'}, {'ali...  $$$$           266
# 13  [{'alias': 'gastropubs', 'title': 'Gastropubs'...    $$           132
# 14            [{'alias': 'bbq', 'title': 'Barbeque'}]    $$           231
# 15  [{'alias': 'newcanadian', 'title': 'Canadian (...   $$$           220
# 16         [{'alias': 'italian', 'title': 'Italian'}]    $$           161
# 17             [{'alias': 'ramen', 'title': 'Ramen'}]    $$           544
# 18  [{'alias': 'cafes', 'title': 'Cafes'}, {'alias...     $            89
# 19             [{'alias': 'pizza', 'title': 'Pizza'}]    $$           274
# 20  [{'alias': 'fishnchips', 'title': 'Fish & Chip...    $$           327
# 21           [{'alias': 'polish', 'title': 'Polish'}]    $$           231
# 22  [{'alias': 'german', 'title': 'German'}, {'ali...    $$            87
# 23   [{'alias': 'sandwiches', 'title': 'Sandwiches'}]     $          1068
# 24  [{'alias': 'himalayan', 'title': 'Himalayan/Ne...    $$           234
# 25     [{'alias': 'creperies', 'title': 'Creperies'}]    $$            73
# 26  [{'alias': 'japanese', 'title': 'Japanese'}, {...    $$           315
# 27  [{'alias': 'italian', 'title': 'Italian'}, {'a...    $$            96
# 28  [{'alias': 'cafes', 'title': 'Cafes'}, {'alias...     $           161
# 29  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...    $$            73
# 30  [{'alias': 'persian', 'title': 'Persian/Irania...    $$           120
# 31  [{'alias': 'newcanadian', 'title': 'Canadian (...    $$           226
# 32  [{'alias': 'caribbean', 'title': 'Caribbean'},...     $            62
# 33  [{'alias': 'vietnamese', 'title': 'Vietnamese'...    $$           150
# 34  [{'alias': 'salad', 'title': 'Salad'}, {'alias...     $            55
# 35  [{'alias': 'sandwiches', 'title': 'Sandwiches'...    $$           342
# 36           [{'alias': 'french', 'title': 'French'}]    $$            85
# 37   [{'alias': 'sandwiches', 'title': 'Sandwiches'}]     $           324
# 38  [{'alias': 'cocktailbars', 'title': 'Cocktail ...    $$            39
# 39  [{'alias': 'himalayan', 'title': 'Himalayan/Ne...     $            99
# 40  [{'alias': 'japanese', 'title': 'Japanese'}, {...   $$$           672
# 41  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...    $$           231
# 42  [{'alias': 'japanese', 'title': 'Japanese'}, {...    $$            68
# 43  [{'alias': 'newcanadian', 'title': 'Canadian (...    $$           101
# 44  [{'alias': 'japanese', 'title': 'Japanese'}, {...    $$          1492
# 45  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     $            79
# 46  [{'alias': 'cocktailbars', 'title': 'Cocktail ...    $$           194
# 47  [{'alias': 'newcanadian', 'title': 'Canadian (...  $$$$           246
# 48  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...     $           196
# 49  [{'alias': 'himalayan', 'title': 'Himalayan/Ne...                  40

# %%
#Save to a CSV all data retrieved
#df_sort_ny.to_csv("NewYork.csv", sep=',',index=False)
df_to.to_csv("Toronto.csv", sep=',',index=False)

# %% [markdown]
# # 2) New York

# %%
# Perform API Calls - test with one restaurant 

params_ny = {'term':'restaurant',
     'location':'New York', 
     'sort_by': 'rating',        
     'limit':'50'}

# %%
request=requests.get(url, params=params_ny, headers=headers)
print('The status code is {}'.format(request.status_code))
# Out:
# The status code is 200

# %%
#Convert the data into a JSON object
parsed_ny = json.loads(request.text)
newyork = parsed_ny["businesses"]

# %%
#print parsed to get an idea how it looks like
#print(json.dumps(parsed_ny, indent=4))

# %%
#“businesses” is a list, enclosed by a square brackets.
# extract businesses first into a Python list and then loop over the businesses in the list.
count = 1
name = []
address = []
city = []
stars = []
category = []
cost = []
review_count = []

for business in newyork:
    #print("Number:", count)
    #print("Name:", business["name"])
    #print("Address:", " ".join(business["location"]["display_address"]))
    #print("City:", " ".join(business["location"]["city"]))
    #print("Rating:", business["rating"])
    #print("Category:", business["categories"])
        
    #if 'price' in business:
    #    print("Cost:", business["price"])
    #
    #print("\n")
    #print("Review Count:", business["review_count"])
    
    name.append(business["name"])
    address.append(business["location"]["display_address"])
    city.append(business["location"]["city"])
    stars.append(business["rating"])
    category.append(business["categories"])
    
    if 'price' in business:
        cost.append(business["price"])
    else:
        cost.append("")
    review_count.append(business["review_count"])

    count = count+1

# %%
#Display the DataFrame

df_ny = pd.DataFrame(data={"Restaurant Name": name, "Restaurant Address": address, "Restaurant City": city, "Stars":
                       stars, "Category": category, "Cost": cost, "Review Count": review_count})
df_ny
#df_sort_ny = df_ny.sort_values(by=['Review Count'], ascending=False)
#df_sort_ny
# Out:
#                   Restaurant Name  \
# 0                            Otis
# 1                      The Alcove
# 2                 Taste of Heaven
# 3                   Korai Kitchen
# 4                Andrea Salumeria
# 5            L'industrie Pizzeria
# 6                  Los Tacos No.1
# 7          Royal Grill Halal Food
# 8                   Miscelanea NY
# 9   Hold Fast Kitchen and Spirits
# 10               Green Juice Cafe
# 11                 Joey Bats Café
# 12                     Cafe Talya
# 13                 Los Tacos No.1
# 14                 Non Solo Piada
# 15      Koroni Souvlaki and Grill
# 16    Sal, Kris, & Charlie's Deli
# 17                    Pita Palace
# 18                  Samurai Sushi
# 19           Frenchy's Food Truck
# 20         Tony's Beechhurst Deli
# 21               Baba's Pierogies
# 22      Sushi by Bou Times Square
# 23           Second Street Bakery
# 24               Lella Alimentari
# 25                      Sushi Lin
# 26                    Casa d'Paco
# 27                   Los Mariscos
# 28              191 Knickerbocker
# 29          Fiore Deli of Hoboken
# 30                         Jajaja
# 31                  Mughlai Grill
# 32             Sami's Kabab House
# 33                  Laojie Hotpot
# 34            4 Charles Prime Rib
# 35        Aux Merveilleux De Fred
# 36               Tres Leches Cafe
# 37                Kafe Louverture
# 38                Mysttik Masaala
# 39     Sorriso Italian Pork Store
# 40                     Griot Cafe
# 41               Panzerotti Bites
# 42                   Dian Kitchen
# 43            Three Seat Espresso
# 44                 Loi Estiatorio
# 45          Lillo Cucina Italiana
# 46               Frisson Espresso
# 47             Top Thai Greenwich
# 48             Joe's Italian Deli
# 49                        Ruffian
#
#                                    Restaurant Address  Restaurant City  Stars  \
# 0                [18 Harrison Pl, Brooklyn, NY 11206]         Brooklyn    5.0
# 1                [41-11 49th St, Sunnyside, NY 11104]        Sunnyside    5.0
# 2                [251 Jackson St, Brooklyn, NY 11211]         Brooklyn    5.0
# 3             [576 Summit Ave, Jersey City, NJ 07306]      Jersey City    5.0
# 4     [247 Central Ave, Apt 3, Jersey City, NJ 07307]      Jersey City    5.0
# 5                  [254 S 2nd St, Brooklyn, NY 11211]         Brooklyn    5.0
# 6                 [229 W 43rd St, New York, NY 10036]         New York    4.5
# 7           [44th St And 6th Ave, New York, NY 10036]         New York    5.0
# 8                   [63 E 4th St, New York, NY 10003]         New York    5.0
# 9                  [364 W46th St, New York, NY 10036]         New York    5.0
# 10                [4316 Broadway, New York, NY 10033]         New York    5.0
# 11                 [129 Allen St, New York, NY 10002]         New York    5.0
# 12                     [218 Ave B, Bayonne, NJ 07002]          Bayonne    5.0
# 13                   [75 9th Ave, New York, NY 10011]         New York    4.5
# 14                [302 W 37th St, New York, NY 10018]         New York    5.0
# 15             [29-37 Newtown Ave, Astoria, NY 11102]          Astoria    5.0
[{'alias': 'coffee', 'title': 'Coffee & Tea'},...   $$           339
# 9   [{'alias': 'cocktailbars', 'title': 'Cocktail ...   $$           156
# 10  [{'alias': 'sandwiches', 'title': 'Sandwiches'...    $           165
# 11  [{'alias': 'desserts', 'title': 'Desserts'}, {...    $           146
# 12  [{'alias': 'cafes', 'title': 'Cafes'}, {'alias...    $           222
# 13             [{'alias': 'tacos', 'title': 'Tacos'}]    $          2633
# 14  [{'alias': 'italian', 'title': 'Italian'}, {'a...   $$           278
# 15  [{'alias': 'mediterranean', 'title': 'Mediterr...   $$           206
# 16  [{'alias': 'delis', 'title': 'Delis'}, {'alias...    $           976
# 17  [{'alias': 'mideastern', 'title': 'Middle East...    $           210
# 18  [{'alias': 'japanese', 'title': 'Japanese'}, {...   $$           148
# 19  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...    $            60
# 20  [{'alias': 'delis', 'title': 'Delis'}, {'alias...   $$           152
# 21  [{'alias': 'modern_european', 'title': 'Modern...   $$           349
# 22  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...  $$$           344
# 23  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...    $           184
# 24  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...    $           159
# 25  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...  $$$           206
# 26  [{'alias': 'spanish', 'title': 'Spanish'}, {'a...   $$           533
# 27  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...    $           472
# 28  [{'alias': 'breakfast_brunch', 'title': 'Break...   $$            82
# 29  [{'alias': 'delis', 'title': 'Delis'}, {'alias...    $           485
# 30  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...   $$           639
# 31           [{'alias': 'indpak', 'title': 'Indian'}]   $$           276
# 32  [{'alias': 'afghani', 'title': 'Afghan'}, {'al...   $$           297
# 33          [{'alias': 'hotpot', 'title': 'Hot Pot'}]   $$           435
# 34  [{'alias': 'steak', 'title': 'Steakhouses'}, {...  $$$           193
# 35  [{'alias': 'desserts', 'title': 'Desserts'}, {...   $$           309
# 36  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...    $            94
# 37  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...    $            97
# 38  [{'alias': 'foodtrucks', 'title': 'Food Trucks...    $           350
# 39  [{'alias': 'meats', 'title': 'Meat Shops'}, {'...    $           313
# 40  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...   $$            93
# 41         [{'alias': 'italian', 'title': 'Italian'}]   $$            80
# 42  [{'alias': 'chinese', 'title': 'Chinese'}, {'a...   $$           132
# 43  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...   $$           178
# 44  [{'alias': 'greek', 'title': 'Greek'}, {'alias...  $$$           318
# 45  [{'alias': 'cafes', 'title': 'Cafes'}, {'alias...    $            75
# 46  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...    $           643
# 47  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...   $$          1069
# 48  [{'alias': 'delis', 'title': 'Delis'}, {'alias...   $$            98
# 49  [{'alias': 'wine_bars', 'title': 'Wine Bars'},...   $$           186

# %%
#Save to a CSV all data retrieved
#df_sort_ny.to_csv("NewYork.csv", sep=',',index=False)
df_ny.to_csv("NewYork.csv", sep=',',index=False)

# %% [markdown]
# # 3) London

# %%
# Perform API Calls - test with one restaurant 
params_ld = {'term':'restaurant',
             'location':'London', 
             'sort_by': 'rating',    
             'limit':'50'}

# %%
request=requests.get(url, params=params_ld, headers=headers)
print('The status code is {}'.format(request.status_code))
# Out:
# The status code is 200

# %%
#Convert the data into a JSON object
parsed_ld = json.loads(request.text)
london = parsed_ld["businesses"]

# %%
#“businesses” is a list, enclosed by a square brackets.
# extract businesses first into a Python list and then loop over the businesses in the list.
count = 1
name = []
address = []
city = []
stars = []
category = []
cost = []
review_count = []

for business in london:
    #print("Number:", count)
    #print("Name:", business["name"])
    #print("Address:", " ".join(business["location"]["display_address"]))
    #print("City:", " ".join(business["location"]["city"]))
    #print("Rating:", business["rating"])
    #print("Category:", business["categories"])
        
    #if 'price' in business:
    #    print("Cost:", business["price"])
    #
    #print("\n")
    #print("Review Count:", business["review_count"])
    
    name.append(business["name"])
    address.append(business["location"]["display_address"])
    city.append(business["location"]["city"])
    stars.append(business["rating"])
    category.append(business["categories"])
    
    if 'price' in business:
        cost.append(business["price"])
    else:
        cost.append("")
    review_count.append(business["review_count"])

    count = count+1

# %%
#Display the DataFrame
df_ld = pd.DataFrame(data={"Restaurant Name": name, "Restaurant Address": address, "Restaurant City": city, "Stars":
                       stars, "Category": category, "Cost": cost, "Review Count": review_count})

df_ld
#df_sort_ld = df_ld.sort_values(by=['Review Count'], ascending=False)
#df_sort_ld
# Out:
#                 Restaurant Name  \
# 0             The Golden Chippy
# 1           Ffiona's Restaurant
# 2                       Dishoom
# 3       Bailey's Fish and Chips
# 4          Kennington Lane Cafe
# 5                       Dishoom
# 6                       Dishoom
# 7                  Regency Café
# 8                   The Ledbury
# 9                     Flat Iron
# 10                      Dishoom
# 11       The Palomar Restaurant
# 12        Hawksmoor Seven Dials
# 13     Restaurant Gordon Ramsay
# 14                      Padella
# 15  Dinner by Heston Blumenthal
# 16                     Bageriet
# 17                    Flat Iron
# 18              Friends of Ours
# 19        Homeslice Neal's Yard
# 20                   Il Portico
# 21                   E Pellicci
# 22               Honest Burgers
# 23     Orjowan Lebanese Cuisine
# 24         Dishoom - Kensington
# 25                  The Barbary
# 26             The Harwood Arms
# 27                 The Fat Bear
# 28                 Ozone Coffee
# 29                    Barrafina
# 30                Pimlico Fresh
# 31            Quilon Restaurant
# 32                 Franco Manca
# 33                      Goodman
# 34                    Kanada-Ya
# 35   The Tiroler Hut Restaurant
# 36                    Blacklock
# 37                  Pizza Union
# 38                  Mother Mash
# 39       Hawksmoor Spitalfields
# 40          The Pig and Butcher
# 41   St John Bar and Restaurant
# 42                 Savoir Faire
# 43           Big Apple Hot Dogs
# 44             Burger & Lobster
# 45                 The Victoria
# 46                    Hawksmoor
# 47                         NOPI
# 48                    Barrafina
# 49                       Petrus
#
#                                    Restaurant Address Restaurant City  Stars  \
# 0   [62 Greenwich High Road, Greenwich, London SE1...          London    5.0
# 1   [51 Kensington Church Street, London W8 4BA, U...          London    4.5
# 2   [22 Kingly Street, London W1B 5QP, United King...          London    4.5
# 3   [115 Dawes Road, Fulham, London SW6 7EQ, Unite...          London    4.5
# 4   [383 Kennington Lane, Vauxhall, London SE11 5Q...          London    5.0
# 5   [12 Upper Saint Martin's Lane, London WC2H 9FB...          London    4.5
# 6   [5 Stable Street, London N1C 4AB, United Kingdom]          London    4.5
# 7   [17-19 Regency Street, London SW1P 4BY, United...          London    4.5
# 8   [127 Ledbury Road, London W11 2AQ, United King...          London    4.5
# 9   [17-18 Henrietta Street, Covent Garden WC2E 8Q...   Covent Garden    4.5
# 10  [7 Boundary Street, London E2 7JE, United King...          London    4.5
# 11  [34 Rupert Street, London W1D 6DN, United King...          London    4.5
# 12  [11 Langley Street, London WC2H 9JG, United Ki...          London    4.5
# 13  [68 Royal Hospital Road, London SW3 4HP, Unite...          London    4.5
# 14  [6 Southwark Street, London SE1 1TQ, United Ki...          London    4.5
# 15  [66 Knightsbridge, Mandarin Oriental at Hyde P...          London    4.5
# 16  [24 Rose Street, London WC2E 9EA, United Kingdom]          London    5.0
# 17  [17 Beak Street, Soho, London W1F 9RW, United ...          London    4.5
# 18  [61 Pitfield Street, London N1 6BU, United Kin...          London    4.5
# 19  [13 Neal's Yard, Covent Garden, London WC2H 9D...          London    4.5
# 20  [277 Kensington High Street, London W8 6NA, Un...          London    5.0
# 21  [332 Bethnal Green Road, London E2 0AG, United...          London    4.5
# 22  [4A Meard Street, London W1F 0EF, United Kingdom]          London    4.5
# 23  [6 Kenway Road, Earl's Court, London SW5 0RR, ...          London    4.5
# 24  [4 Derry Street, Kensington W8 5SE, United Kin...      Kensington    4.5
# 25  [16 Neal's Yard, Seven Dials, London WC2H 9DP,...          London    4.5
# 26  [27 Walham Grove, Fulham, London SW6 1QP, Unit...          London    4.5
# 27  [61 Carter Lane, London EC4V 5DY, United Kingdom]          London    4.5
# 28  [11 Leonard Street, London EC2A 4AQ, United Ki...          London    4.5
# 29  [10 Adelaide Street, London WC2N 4HZ, United K...          London    4.5
# 30  [85 Wilton Road, London SW1V 1DE, United Kingdom]          London    4.5
# 31  [41 Buckingham Gate, London SW1E 6AF, United K...          London    4.5
# 32  [4 Market Row, Electric Lane, London SW9 8LD, ...          London    4.5
# 33  [26 Maddox Street, London W1S 1QH, United King...          London    4.5
# 34  [64 St Giles High Street, London WC2H 8LE, Uni...          London    4.5
# 35  [27 Westbourne Grove, London W2 4UA, United Ki...          London    4.5
# 36  [The Basement, 24 Great Windmill Street, Londo...          London    4.5
# 37  [25 Sandy's Row, Corner of Middlesex Street, S...          London    4.5
# 38  [26 Ganton Street, London W1F 7QZ, United King...          London    4.0
# 39  [157a Commercial Street, London E1 6BJ, United...          London    4.5
# 40  [80 Liverpool Road, London N1 0QD, United King...          London    4.5
# 41  [26 St John Street, London EC1M 4AY, United Ki...          London    4.0
# 42  [42 New Oxford Street, London WC1A 1EP, United...          London    4.5
# 43  [Cole & Sons, 170 Caledonian Rd, Kings Cross, ...          London    4.5
# 44  [29 Clarges Street, Mayfair W1J 7EF, United Ki...         Mayfair    4.5
# 45  [10a Strathearn Place, Paddington W2 2NH, Unit...      Paddington    4.5
# 46    [5A Air Street, London W1J 0AD, United Kingdom]          London    4.5
# 47  [21-22 Warwick Street, London W1B 5NE, United ...          London    4.0
# 48  [43 Drury Lane, Covent Garden, London WC2B 5RT...          London    4.5
# 49  [1 Kinnerton Street, Knightsbridge, London SW1...          London    4.5
#
#                                              Category  Cost  Review Count
# 0   [{'alias': 'fishnchips', 'title': 'Fish & Chip...    ££            67
# 1          [{'alias': 'british', 'title': 'British'}]    ££           236
# 2            [{'alias': 'indpak', 'title': 'Indian'}]    ££           432
# 3   [{'alias': 'fishnchips', 'title': 'Fish & Chip...     £           119
# 4              [{'alias': 'cafes', 'title': 'Cafes'}]     £            63
# 5            [{'alias': 'indpak', 'title': 'Indian'}]    ££          1598
# 6   [{'alias': 'indpak', 'title': 'Indian'}, {'ali...    ££           325
# 7   [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     £           368
# 8   [{'alias': 'modern_european', 'title': 'Modern...  ££££           161
# 9        [{'alias': 'steak', 'title': 'Steakhouses'}]    ££           160
# 10  [{'alias': 'indpak', 'title': 'Indian'}, {'ali...    ££           413
# 11  [{'alias': 'mideastern', 'title': 'Middle East...   £££            90
# 12  [{'alias': 'british', 'title': 'British'}, {'a...   £££           320
# 13  [{'alias': 'french', 'title': 'French'}, {'ali...  ££££           192
# 14         [{'alias': 'italian', 'title': 'Italian'}]    ££           155
# 15         [{'alias': 'british', 'title': 'British'}]  ££££           276
# 16  [{'alias': 'scandinavian', 'title': 'Scandinav...     £            59
# 17       [{'alias': 'steak', 'title': 'Steakhouses'}]    ££           338
# 18             [{'alias': 'cafes', 'title': 'Cafes'}]    ££            87
# 19             [{'alias': 'pizza', 'title': 'Pizza'}]    ££           210
# 20         [{'alias': 'italian', 'title': 'Italian'}]   £££            48
# 21  [{'alias': 'italian', 'title': 'Italian'}, {'a...     £            80
# 22         [{'alias': 'burgers', 'title': 'Burgers'}]    ££           259
# 23  [{'alias': 'mideastern', 'title': 'Middle East...    ££            88
# 24           [{'alias': 'indpak', 'title': 'Indian'}]    ££            77
# 25  [{'alias': 'mideastern', 'title': 'Middle East...   £££            50
# 26  [{'alias': 'gastropubs', 'title': 'Gastropubs'...   £££           116
# 27  [{'alias': 'tradamerican', 'title': 'American ...    ££           107
# 28  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...    ££           176
# 29         [{'alias': 'spanish', 'title': 'Spanish'}]   £££            60
# 30  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...    ££           142
# 31           [{'alias': 'indpak', 'title': 'Indian'}]   £££           143
# 32  [{'alias': 'italian', 'title': 'Italian'}, {'a...     £           168
# 33  [{'alias': 'steak', 'title': 'Steakhouses'}, {...   £££           104
# 34             [{'alias': 'ramen', 'title': 'Ramen'}]    ££           141
# 35  [{'alias': 'german', 'title': 'German'}, {'ali...    ££            67
# 36  [{'alias': 'british', 'title': 'British'}, {'a...   £££            79
# 37             [{'alias': 'pizza', 'title': 'Pizza'}]     £            81
# 38         [{'alias': 'british', 'title': 'British'}]    ££           414
# 39  [{'alias': 'steak', 'title': 'Steakhouses'}, {...   £££           169
# 40  [{'alias': 'british', 'title': 'British'}, {'a...    ££            93
# 41  [{'alias': 'british', 'title': 'British'}, {'a...   £££           284
# 42           [{'alias': 'french', 'title': 'French'}]    ££           187
# 43  [{'alias': 'hotdog', 'title': 'Hot Dogs'}, {'a...    ££            47
# 44  [{'alias': 'tradamerican', 'title': 'American ...   £££           211
# 45  [{'alias': 'pubs', 'title': 'Pubs'}, {'alias':...    ££           173
# 46  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...   £££           139
# 47  [{'alias': 'mediterranean', 'title': 'Mediterr...   £££           253
# 48  [{'alias': 'spanish', 'title': 'Spanish'}, {'a...    ££            52
# 49           [{'alias': 'french', 'title': 'French'}]  ££££           101

# %%
#Save to a CSV all data retrieved
#df_sort_ld.to_csv("London.csv", sep=',',index=False)
df_ld.to_csv("London.csv", sep=',',index=False)

# %% [markdown]
# # 4) Paris

# %%
# Perform API Calls - test with one restaurant 
params_ps = {'term':'restaurant',
             'location':'Paris', 
             'sort_by': 'rating',  
             'limit':50}

# %%
request=requests.get(url, params=params_ps, headers=headers)
print('The status code is {}'.format(request.status_code))
# Out:
# The status code is 200

# %%
#Convert the data into a JSON object
parsed_ps = json.loads(request.text)
paris = parsed_ps["businesses"]

# %%
#“businesses” is a list, enclosed by a square brackets.
# extract businesses first into a Python list and then loop over the businesses in the list.
count = 1
name = []
address = []
city = []
stars = []
category = []
cost = []
review_count = []

for business in paris:
    #print("Number:", count)
    #print("Name:", business["name"])
    #print("Address:", " ".join(business["location"]["display_address"]))
    #print("City:", " ".join(business["location"]["city"]))
    #print("Rating:", business["rating"])
    #print("Category:", business["categories"])
        
    #if 'price' in business:
    #    print("Cost:", business["price"])
    #
    #print("\n")
    #print("Review Count:", business["review_count"])
    
    name.append(business["name"])
    address.append(business["location"]["display_address"])
    city.append(business["location"]["city"])
    stars.append(business["rating"])
    category.append(business["categories"])
    
    if 'price' in business:
        cost.append(business["price"])
    else:
        cost.append("")
    review_count.append(business["review_count"])

    count = count+1

# %%
#Display the DataFrame
df_ps = pd.DataFrame(data={"Restaurant Name": name, "Restaurant Address": address, "Restaurant City": city, "Stars":
                       stars, "Category": category, "Cost": cost, "Review Count": review_count})

df_ps
#df_sort_ps = df_ps.sort_values(by=['Review Count'], ascending=False)
#df_sort_ps
# Out:
#                   Restaurant Name  \
# 0      Le Potager du Père Thierry
# 1                  La Coïncidence
# 2   Le Comptoir de la Gastronomie
# 3                Le Volant Basque
# 4                       Holybelly
# 5                         Fraîche
# 6                         Le Cinq
# 7                     Pizza Julia
# 8        Le Bistrot des Augustins
# 9            Chez Alain Miam Miam
# 10               L'Avant Comptoir
# 11                 Baguett's Café
# 12                      L'Epicure
# 13                        Le Hide
# 14       La Vache et le Cuisinier
# 15                       Sanukiya
# 16         La Droguerie du Marais
# 17          Le Bistro du Périgord
# 18                Le Petit Canard
# 19              Chez Mademoiselle
# 20           Crêperie Brocéliande
# 21                   Al Caratello
# 22       Le Bistrot des Campagnes
# 23                  Little Breizh
# 24                   Soul Kitchen
# 25               Chez le Libanais
# 26               L'As du Fallafel
# 27                   Galette Café
# 28                 La Cordonnerie
# 29           Le Temps des Cerises
# 30           The Hardware Société
# 31              Reed - Restaurant
# 32                   Les Papilles
# 33           Bar Italia Brasserie
# 34                    La Jacobine
# 35                     L'Alsacien
# 36            Matamata Coffee Bar
# 37            Le Jardin d'en Face
# 38                   Sacrée Fleur
# 39               Pizzeria Babalou
# 40         Crêperie le Crépuscule
# 41                    L'Estrapade
# 42                Les Antiquaires
# 43                         Miznon
# 44            L'Ardoise Gourmande
# 45                        Banh Mi
# 46              La Cave Gourmande
# 47         Au Pied du Sacré Coeur
# 48                         Verjus
# 49                 Chez Gabrielle
#
#                                    Restaurant Address Restaurant City  Stars  \
# 0      [16 rue des Trois Frères, 75018 Paris, France]           Paris    4.5
# 1                [15 rue Mesnil, 75116 Paris, France]           Paris    4.5
# 2            [34 rue Montmartre, 75001 Paris, France]           Paris    4.5
# 3       [13 rue Béatrix Dussane, 75015 Paris, France]           Paris    4.5
# 4         [5 rue Lucien Sampaix, 75010 Paris, France]           Paris    4.5
# 5            [8 rue Vicq d'Azir, 75010 Paris, France]           Paris    4.5
# 49           [7 rue de l'Etoile, 75017 Paris, France]           Paris    4.5
#
#                                              Category  Cost  Review Count
# 0            [{'alias': 'french', 'title': 'French'}]    €€           392
# 1            [{'alias': 'french', 'title': 'French'}]    €€           417
# 2            [{'alias': 'french', 'title': 'French'}]    €€           872
# 3            [{'alias': 'basque', 'title': 'Basque'}]    €€           201
# 4   [{'alias': 'breakfast_brunch', 'title': 'Break...    €€           155
# 5            [{'alias': 'french', 'title': 'French'}]   €€€            99
# 6            [{'alias': 'french', 'title': 'French'}]  €€€€           122
# 7              [{'alias': 'pizza', 'title': 'Pizza'}]     €           127
# 8   [{'alias': 'bistros', 'title': 'Bistros'}, {'a...    €€           322
# 9   [{'alias': 'creperies', 'title': 'Creperies'},...     €           132
# 10  [{'alias': 'tapas', 'title': 'Tapas Bars'}, {'...    €€           576
# 11  [{'alias': 'cafes', 'title': 'Cafes'}, {'alias...    €€           161
# 12  [{'alias': 'french', 'title': 'French'}, {'ali...  €€€€           150
# 13           [{'alias': 'french', 'title': 'French'}]   €€€           193
# 14           [{'alias': 'french', 'title': 'French'}]   €€€            58
# 15       [{'alias': 'japanese', 'title': 'Japanese'}]    €€           305
# 16     [{'alias': 'creperies', 'title': 'Creperies'}]     €           176
# 17         [{'alias': 'bistros', 'title': 'Bistros'}]   €€€           332
# 18           [{'alias': 'french', 'title': 'French'}]    €€           163
# 19           [{'alias': 'french', 'title': 'French'}]   €€€            88
# 20  [{'alias': 'creperies', 'title': 'Creperies'},...    €€           116
# 21         [{'alias': 'italian', 'title': 'Italian'}]    €€           159
# 22         [{'alias': 'bistros', 'title': 'Bistros'}]    €€           117
# 23     [{'alias': 'creperies', 'title': 'Creperies'}]    €€           188
# 24  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...    €€           129
# 25       [{'alias': 'lebanese', 'title': 'Lebanese'}]     €           164
# 26  [{'alias': 'kosher', 'title': 'Kosher'}, {'ali...     €          1658
# 27     [{'alias': 'creperies', 'title': 'Creperies'}]    €€            98
# 28           [{'alias': 'french', 'title': 'French'}]   €€€            74
# 29         [{'alias': 'bistros', 'title': 'Bistros'}]    €€           304
# 30  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...    €€           134
# 31           [{'alias': 'french', 'title': 'French'}]   €€€            48
# 32  [{'alias': 'wine_bars', 'title': 'Wine Bars'},...   €€€           230
# 33         [{'alias': 'italian', 'title': 'Italian'}]   €€€            41
# 34  [{'alias': 'tea', 'title': 'Tea Rooms'}, {'ali...   €€€           247
# 35  [{'alias': 'beerbar', 'title': 'Beer Bar'}, {'...    €€            61
# 36  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     €            75
# 37           [{'alias': 'french', 'title': 'French'}]    €€            82
# 38           [{'alias': 'french', 'title': 'French'}]   €€€            87
# 39  [{'alias': 'italian', 'title': 'Italian'}, {'a...    €€           155
# 40     [{'alias': 'creperies', 'title': 'Creperies'}]    €€            62
# 41           [{'alias': 'french', 'title': 'French'}]   €€€            42
# 42           [{'alias': 'french', 'title': 'French'}]    €€           241
# 43  [{'alias': 'kosher', 'title': 'Kosher'}, {'ali...    €€           145
# 44           [{'alias': 'french', 'title': 'French'}]    €€            81
# 45  [{'alias': 'vietnamese', 'title': 'Vietnamese'...     €           148
# 46           [{'alias': 'french', 'title': 'French'}]    €€           282
# 47           [{'alias': 'french', 'title': 'French'}]    €€           159
# 48  [{'alias': 'modern_european', 'title': 'Modern...  €€€€           137
# 49           [{'alias': 'french', 'title': 'French'}]   €€€            59

# %%
#Save to a CSV all data retrieved
#df_sort_ps.to_csv("Paris.csv", sep=',',index=False)
df_ps.to_csv("Paris.csv", sep=',',index=False)

# %% [markdown]
# # 5) Tokyo

# %%
# Perform API Calls - test with one restaurant 
params_tk = {'term':'restaurant',
             'location':'Tokyo', 
             'sort_by': 'rating',    
             'limit':'50'}

# %%
request=requests.get(url, params=params_tk, headers=headers)
print('The status code is {}'.format(request.status_code))
# Out:
# The status code is 200

# %%
#Convert the data into a JSON object
parsed_tk = json.loads(request.text)
tokyo = parsed_tk["businesses"]

# %%
#“businesses” is a list, enclosed by a square brackets.
# extract businesses first into a Python list and then loop over the businesses in the list.
count = 1
name = []
address = []
city = []
stars = []
category = []
cost = []
review_count = []

for business in tokyo:
    #print("Number:", count)
    #print("Name:", business["name"])
    #print("Address:", " ".join(business["location"]["display_address"]))
    #print("City:", " ".join(business["location"]["city"]))
    #print("Rating:", business["rating"])
    #print("Category:", business["categories"])
        
    #if 'price' in business:
    #    print("Cost:", business["price"])
    #
    #print("\n")
    #print("Review Count:", business["review_count"])
    
    name.append(business["name"])
    address.append(business["location"]["display_address"])
    city.append(business["location"]["city"])
    stars.append(business["rating"])
    category.append(business["categories"])
    
    if 'price' in business:
        cost.append(business["price"])
    else:
        cost.append("")
    review_count.append(business["review_count"])

    count = count+1

# %%
#Display the DataFrame
df_tk = pd.DataFrame(data={"Restaurant Name": name, "Restaurant Address": address, "Restaurant City": city, "Stars":
                       stars, "Category": category, "Cost": cost, "Review Count": review_count})

#df_sort_tk = df_tk.sort_values(by=['Review Count'], ascending=False)
#df_sort_tk
df_tk
# Out:
#                                       Restaurant Name  \
# 0                  Ichiran Shinjuku Chuo Higashiguchi
# 1              Gyukatsu MOTOMURA Tokyo Eki Yaesuguchi
# 2                                     Ichiran Shibuya
# 3                                       Sushisho Masa
# 4              Uogashi Nihon Ichi Shinjuku Nishiguchi
# 5                                             Hakushu
# 6                           Gyūkatsu Motomura Shibuya
# 7                                        Ippudo Ginza
# 8               T's Tantan Tokyo Station Keiyo Street
# 9                                        Kyubey Ginza
# 10                                      AKIBA FUKUROU
# 11                         Gyukatsu Motomura Shinjuku
# 12                       Karashibi Miso Ramen Kikanbo
# 13                                          Udon Shin
# 14                                             Fuunji
# 15               Abura Soba Tōkyō Aburagumi Sōhonten
# 16                             Sapporo DOMINICA Ginza
# 17                         Fūryū Okonomiyaki Sometarō
# 18                           Jirōmaru Shinjuku Honten
# 19                        Japanese Soba Noodles Tsuta
# 20                    Sukiyabashi Jiro Roppongi Hills
# 21                                          Tatsunoya
# 22                          Ichiran Shibuya Spainzaka
# 23                                      Turret COFFEE
# 24                                           Mutekiya
# 25                      Tonkatsu Maisen Aoyama Honten
# 26                   Kaiten Zushi Katsu Seibu Shibuya
# 27                                            NAKIRYU
# 28  Uogashi Nihonichi Tachigui Sushi SHIBUYA CENTE...
# 29                                           Narisawa
# 30                                             Marugo
# 2              [{'alias': 'ramen', 'title': 'Ramen'}]     ￥           529
# 3         [{'alias': 'sushi', 'title': 'Sushi Bars'}]  ￥￥￥￥            49
# 4         [{'alias': 'sushi', 'title': 'Sushi Bars'}]     ￥            89
# 5   [{'alias': 'steak', 'title': 'Steakhouses'}, {...   ￥￥￥            85
# 6   [{'alias': 'tempura', 'title': 'Tempura'}, {'a...     ￥           101
# 7   [{'alias': 'ramen', 'title': 'Ramen'}, {'alias...     ￥           179
# 8   [{'alias': 'vegan', 'title': 'Vegan'}, {'alias...     ￥           148
# 9         [{'alias': 'sushi', 'title': 'Sushi Bars'}]  ￥￥￥￥           106
# 10  [{'alias': 'themedcafes', 'title': 'Themed Caf...     ￥            66
# 11  [{'alias': 'tempura', 'title': 'Tempura'}, {'a...    ￥￥            72
# 12             [{'alias': 'ramen', 'title': 'Ramen'}]     ￥            84
# 13               [{'alias': 'udon', 'title': 'Udon'}]     ￥           144
# 14             [{'alias': 'ramen', 'title': 'Ramen'}]     ￥           197
# 15  [{'alias': 'ramen', 'title': 'Ramen'}, {'alias...     ￥            55
# 16  [{'alias': 'japacurry', 'title': 'Japanese Cur...     ￥            56
# 17  [{'alias': 'okonomiyaki', 'title': 'Okonomiyak...     ￥            86
# 18       [{'alias': 'yakiniku', 'title': 'Yakiniku'}]    ￥￥           182
# 19             [{'alias': 'ramen', 'title': 'Ramen'}]     ￥           168
# 20        [{'alias': 'sushi', 'title': 'Sushi Bars'}]  ￥￥￥￥            86
# 21  [{'alias': 'ramen', 'title': 'Ramen'}, {'alias...     ￥            60
# 22             [{'alias': 'ramen', 'title': 'Ramen'}]     ￥            51
# 23  [{'alias': 'cafes', 'title': 'Cafes'}, {'alias...     ￥            86
# 24             [{'alias': 'ramen', 'title': 'Ramen'}]     ￥            87
# 25  [{'alias': 'tonkatsu', 'title': 'Tonkatsu'}, {...    ￥￥           161
# 26  [{'alias': 'conveyorsushi', 'title': 'Conveyor...    ￥￥            90
# 27  [{'alias': 'ramen', 'title': 'Ramen'}, {'alias...     ￥            82
# 28  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...    ￥￥            54
# 29  [{'alias': 'asianfusion', 'title': 'Asian Fusi...  ￥￥￥￥            52
# 30       [{'alias': 'tonkatsu', 'title': 'Tonkatsu'}]    ￥￥            50
# 31       [{'alias': 'sukiyaki', 'title': 'Sukiyaki'}]                  41
# 32             [{'alias': 'ramen', 'title': 'Ramen'}]     ￥           219
# 33             [{'alias': 'ramen', 'title': 'Ramen'}]     ￥           129
# 34  [{'alias': 'steak', 'title': 'Steakhouses'}, {...  ￥￥￥￥            87
# 35        [{'alias': 'sushi', 'title': 'Sushi Bars'}]    ￥￥           123
# 36             [{'alias': 'ramen', 'title': 'Ramen'}]     ￥            43
# 37  [{'alias': 'kaiseki', 'title': 'Kaiseki'}, {'a...   ￥￥￥            36
# 38  [{'alias': 'vegan', 'title': 'Vegan'}, {'alias...     ￥            46
# 39       [{'alias': 'tonkatsu', 'title': 'Tonkatsu'}]     ￥            76
# 40  [{'alias': 'kaiseki', 'title': 'Kaiseki'}, {'a...  ￥￥￥￥            25
# 41             [{'alias': 'ramen', 'title': 'Ramen'}]     ￥            44
# 42  [{'alias': 'tonkatsu', 'title': 'Tonkatsu'}, {...    ￥￥            41
# 43        [{'alias': 'sushi', 'title': 'Sushi Bars'}]    ￥￥            28
# 44  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...    ￥￥           120
# 45  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     ￥            91
# 46        [{'alias': 'sushi', 'title': 'Sushi Bars'}]   ￥￥￥            34
# 47             [{'alias': 'ramen', 'title': 'Ramen'}]     ￥            76
# 48  [{'alias': 'sukiyaki', 'title': 'Sukiyaki'}, {...    ￥￥            86
# 49  [{'alias': 'ramen', 'title': 'Ramen'}, {'alias...     ￥            92

# %%
#Save to a CSV all data retrieved
#df_sort_tk.to_csv("Tokyo.csv", sep=',',index=False)
df_tk.to_csv("Tokyo.csv", sep=',',index=False)
